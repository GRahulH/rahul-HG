# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2024.2.2)

# %%
import folium
mymap=folium.Map(location =[1.366623,103.821285],
width=950,
height=550,
zoom_start=12,
tiles='openstreetmap')
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_62dab047b485d8d68a95099034f44bdd {
#                     position: relative;
#                     width: 950.0px;
#                     height: 550.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_62dab047b485d8d68a95099034f44bdd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_62dab047b485d8d68a95099034f44bdd = L.map(
#                 &quot;map_62dab047b485d8d68a95099034f44bdd&quot;,
#                 {
#                     center: [1.366623, 103.821285],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5e389b62a964b9f70b6dafaf877bcf77 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_62dab047b485d8d68a95099034f44bdd);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# List of locations (latitude, longitude)
locations = [[1.366623,103.821285], [1.283873,103.845202], [1.348382,103.852376]]

# Create a map centered at the first location
mymap = folium.Map(location = locations[0],
                   width=950,
                   height=550,
                   zoom_start=12,
                   tiles='openstreetmap')

# Add markers for each location
for location in locations:
    folium.Marker(location=location).add_to(mymap)

# Display the map
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d6f54a3d88f12e7369aff95a6af04e37 {
#                     position: relative;
#                     width: 950.0px;
#                     height: 550.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d6f54a3d88f12e7369aff95a6af04e37&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d6f54a3d88f12e7369aff95a6af04e37 = L.map(
#                 &quot;map_d6f54a3d88f12e7369aff95a6af04e37&quot;,
#                 {
#                     center: [1.366623, 103.821285],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eb94f997fcb77d53d9f8920c52870e61 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d6f54a3d88f12e7369aff95a6af04e37);
#
#
#             var marker_32273bb3b6cc72c608aae0710f328c68 = L.marker(
#                 [1.366623, 103.821285],
#                 {}
#             ).addTo(map_d6f54a3d88f12e7369aff95a6af04e37);
#
#
#             var marker_60d0a1cd4b4a7816a02a58233d77f1bd = L.marker(
#                 [1.283873, 103.845202],
#                 {}
#             ).addTo(map_d6f54a3d88f12e7369aff95a6af04e37);
#
#
#             var marker_5c4173c7e08520e2d69cb966dd2acbac = L.marker(
#                 [1.348382, 103.852376],
#                 {}
#             ).addTo(map_d6f54a3d88f12e7369aff95a6af04e37);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# List of locations (latitude, longitude)
locations = [[1.366623,103.821285], [1.283873,103.845202], [1.348382,103.852376]]

# List of popup texts
popups = ['Marker 1', 'Marker 2', 'Marker 3']

# Create a map centered at the first location
mymap = folium.Map(location = locations[0],
                   width=950,
                   height=550,
                   zoom_start=12,
                   tiles='openstreetmap')

# Add markers with popups for each location
for location, popup in zip(locations, popups):
    folium.Marker(location=location, popup=popup).add_to(mymap)

# Display the map
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_128b620bf07ab245407832abd9f5d3fe {
#                     position: relative;
#                     width: 950.0px;
#                     height: 550.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_128b620bf07ab245407832abd9f5d3fe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_128b620bf07ab245407832abd9f5d3fe = L.map(
#                 &quot;map_128b620bf07ab245407832abd9f5d3fe&quot;,
#                 {
#                     center: [1.366623, 103.821285],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_57967d4186cfdce12f54d190b6b5742c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_128b620bf07ab245407832abd9f5d3fe);
#
#
#             var marker_36d1f091c9ff7c9bf8465f6445b6c357 = L.marker(
#                 [1.366623, 103.821285],
#                 {}
#             ).addTo(map_128b620bf07ab245407832abd9f5d3fe);
#
#
#         var popup_cdb52baf8eeef0e8eda9112b0b03835e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_361f15577510b1ca0bb89e644de1af76 = $(`&lt;div id=&quot;html_361f15577510b1ca0bb89e644de1af76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_cdb52baf8eeef0e8eda9112b0b03835e.setContent(html_361f15577510b1ca0bb89e644de1af76);
#
#
#
#         marker_36d1f091c9ff7c9bf8465f6445b6c357.bindPopup(popup_cdb52baf8eeef0e8eda9112b0b03835e)
#         ;
#
#
#
#
#             var marker_2972a8a552bb798296b31d0ed90711af = L.marker(
#                 [1.283873, 103.845202],
#                 {}
#             ).addTo(map_128b620bf07ab245407832abd9f5d3fe);
#
#
#         var popup_d4abb02b662b876dc1a2dadc40fda157 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_295eadae928af29a1a90395d495faa68 = $(`&lt;div id=&quot;html_295eadae928af29a1a90395d495faa68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d4abb02b662b876dc1a2dadc40fda157.setContent(html_295eadae928af29a1a90395d495faa68);
#
#
#
#         marker_2972a8a552bb798296b31d0ed90711af.bindPopup(popup_d4abb02b662b876dc1a2dadc40fda157)
#         ;
#
#
#
#
#             var marker_79239a1b13f368c3adc63cd047b4e670 = L.marker(
#                 [1.348382, 103.852376],
#                 {}
#             ).addTo(map_128b620bf07ab245407832abd9f5d3fe);
#
#
#         var popup_117aa40ea19009c53fa341c9157ac93a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d564aa9f3db823cb0b130a8f552e42de = $(`&lt;div id=&quot;html_d564aa9f3db823cb0b130a8f552e42de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_117aa40ea19009c53fa341c9157ac93a.setContent(html_d564aa9f3db823cb0b130a8f552e42de);
#
#
#
#         marker_79239a1b13f368c3adc63cd047b4e670.bindPopup(popup_117aa40ea19009c53fa341c9157ac93a)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# Create a map centered at Bangalore location
mymap = folium.Map(location =[12.9716,77.5946],
                   width=950,
                   height=550,
                   zoom_start=12,
                   tiles='openstreetmap')

# Add a marker to the map
folium.Marker(location=[12.9716,77.5946], popup='Bangalore City').add_to(mymap)

# Display the map
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_facfe95c910c89de4f4c3e8be232a600 {
#                     position: relative;
#                     width: 950.0px;
#                     height: 550.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_facfe95c910c89de4f4c3e8be232a600&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_facfe95c910c89de4f4c3e8be232a600 = L.map(
#                 &quot;map_facfe95c910c89de4f4c3e8be232a600&quot;,
#                 {
#                     center: [12.9716, 77.5946],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c43f4b55288be64b7b0396d830297075 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_facfe95c910c89de4f4c3e8be232a600);
#
#
#             var marker_e4a57a1a9c8ee6f63bade85d14ea691c = L.marker(
#                 [12.9716, 77.5946],
#                 {}
#             ).addTo(map_facfe95c910c89de4f4c3e8be232a600);
#
#
#         var popup_058e675a274b46f7cb1f265aa09dcee6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_55e9ffb492238d6566351dabe6348fca = $(`&lt;div id=&quot;html_55e9ffb492238d6566351dabe6348fca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bangalore City&lt;/div&gt;`)[0];
#                 popup_058e675a274b46f7cb1f265aa09dcee6.setContent(html_55e9ffb492238d6566351dabe6348fca);
#
#
#
#         marker_e4a57a1a9c8ee6f63bade85d14ea691c.bindPopup(popup_058e675a274b46f7cb1f265aa09dcee6)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# Create a map centered at Bangalore location
mymap = folium.Map(location =[12.9716,77.5946],
                   width=950,
                   height=550,
                   zoom_start=12,
                   tiles='openstreetmap')

# Add a marker to the map
folium.Marker(location=[12.9716,77.5946], popup='Bangalore City').add_to(mymap)

# Add an image overlay to the map
folium.raster_layers.ImageOverlay(
    image='https://upload.wikimedia.org/wikipedia/commons/d/d7/Vidhana_Soudha_-_June_2019_%283%29.jpg',
    bounds=[[12.9650, 77.5750], [12.9780, 77.6150]],
    opacity=0.5,
    interactive=True
).add_to(mymap)

# Display the map
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_377240132faf4751a563e168f162f4b7 {
#                     position: relative;
#                     width: 950.0px;
#                     height: 550.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_377240132faf4751a563e168f162f4b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_377240132faf4751a563e168f162f4b7 = L.map(
#                 &quot;map_377240132faf4751a563e168f162f4b7&quot;,
#                 {
#                     center: [12.9716, 77.5946],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a9543dd55d7f78360481a58f729030d6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_377240132faf4751a563e168f162f4b7);
#
#
#             var marker_f52322256384075bec3219dd4fff7add = L.marker(
#                 [12.9716, 77.5946],
#                 {}
#             ).addTo(map_377240132faf4751a563e168f162f4b7);
#
#
#         var popup_3a08ddc660de9fd1f3196fd891a4982c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fe95488d1e10e33aaffb7046589cdab7 = $(`&lt;div id=&quot;html_fe95488d1e10e33aaffb7046589cdab7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bangalore City&lt;/div&gt;`)[0];
#                 popup_3a08ddc660de9fd1f3196fd891a4982c.setContent(html_fe95488d1e10e33aaffb7046589cdab7);
#
#
#
#         marker_f52322256384075bec3219dd4fff7add.bindPopup(popup_3a08ddc660de9fd1f3196fd891a4982c)
#         ;
#
#
#
#
#             var image_overlay_264bbbc4415ee4b1c222fd3fcd02b253 = L.imageOverlay(
#                 &quot;https://upload.wikimedia.org/wikipedia/commons/d/d7/Vidhana_Soudha_-_June_2019_%283%29.jpg&quot;,
#                 [[12.965, 77.575], [12.978, 77.615]],
#                 {&quot;interactive&quot;: true, &quot;opacity&quot;: 0.5}
#             ).addTo(map_377240132faf4751a563e168f162f4b7);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
#BANGLORE MAP WITH FAMOUS PLACES INCLUDING IMAGES
# Latitude and longitude coordinates of Bangalore
bangalore_coords = (12.9716, 77.5946)

# Create a map centered around Bangalore
map_bangalore = folium.Map(location=bangalore_coords, zoom_start=12)

# Define famous places and their coordinates in Bangalore

places = {
    "Lalbagh Botanical Garden": (12.9507, 77.5844),
    "Cubbon Park": (12.9757, 77.5929),
    "Bangalore Palace": (12.97194, 77.5936),
    "Vidhana Soudha": (12.979693, 77.590658),
    "Presidency University": (13.1682, 77.5354),
    "Wonderla": (12.834300, 77.414558)   ,
    "M Chinnaswamy Stadium": (12.9784, 77.5994),
    "Isckon temple": (13.00981, 77.55109),
    "Kempegowda International Airport": (13.192665896, 77.70333052)
}



# Define images for each place
images = {
    "Lalbagh Botanical Garden": "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0c/7d/47/f4/lalbagh-botanical-garden.jpg?w=1200&h=1200&s=1",
    "Cubbon Park": "https://tse1.mm.bing.net/th?id=OIP.G-kjAcQb59k6I1vQ_XcHEwHaE8&pid=Api&P=0&h=180",
    "Bangalore Palace": "https://tse2.mm.bing.net/th?id=OIP.i8dzBHIHgsZ0D9JK9tzSMwHaEo&pid=Api&P=0&h=180",
    "Vidhana Soudha": "https://tse3.mm.bing.net/th?id=OIP.LMgE0-vo4Fk26srdnaMdYgHaFj&pid=Api&P=0&h=180",
    "Presidency University": "https://tse1.mm.bing.net/th?id=OIP.X_YkcFxJv_Hy_fDFMfJv-gHaE8&pid=Api&P=0&h=180",
    "Wonderla": "https://tse2.mm.bing.net/th?id=OIP.p-jWkEz-iJvmLc4PtPFwAAHaE8&pid=Api&P=0&h=180",
    "M Chinnaswamy Stadium": "https://tse1.mm.bing.net/th?id=OIP.NepFTWdG0NbPcLL2XFI-jQHaEK&pid=Api&P=0&h=180",
    "Isckon temple": "https://tse1.mm.bing.net/th?id=OIP.76ttZ61WrTg-a-nuYSpdPAHaFj&pid=Api&P=0&h=180",
    "Kempegowda International Airport": "https://tse4.mm.bing.net/th?id=OIP.tu4IQk62ZmQfQhbIPDfZ8AHaE8&pid=Api&P=0&h=180"
}

# Add markers for each place
for place, coords in places.items():
    popup_content = f'<b>{place}</b><br><img src="{images[place]}" width="200">'
    folium.Marker(location=coords, popup=folium.Popup(popup_content, max_width=300)).add_to(map_bangalore)

# Display the map
map_bangalore
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9d1793ca40ff6fac4b80d3e102708571 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9d1793ca40ff6fac4b80d3e102708571&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9d1793ca40ff6fac4b80d3e102708571 = L.map(
#                 &quot;map_9d1793ca40ff6fac4b80d3e102708571&quot;,
#                 {
#                     center: [12.9716, 77.5946],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c4ff3cc400dd3f6ce18dbfd328fa4b7e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9d1793ca40ff6fac4b80d3e102708571);
#
#
#             var marker_35cb69201407e30b104ee10284bc02dd = L.marker(
#                 [12.9507, 77.5844],
#                 {}
#             ).addTo(map_9d1793ca40ff6fac4b80d3e102708571);
#
#
#         var popup_92dc95bb1983973407a14af72fdf61ce = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_42332d5829e654f21e99f22cbf4172c3 = $(`&lt;div id=&quot;html_42332d5829e654f21e99f22cbf4172c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Lalbagh Botanical Garden&lt;/b&gt;&lt;br&gt;&lt;img src=&quot;https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0c/7d/47/f4/lalbagh-botanical-garden.jpg?w=1200&amp;h=1200&amp;s=1&quot; width=&quot;200&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_92dc95bb1983973407a14af72fdf61ce.setContent(html_42332d5829e654f21e99f22cbf4172c3);
#
#
#
#         marker_35cb69201407e30b104ee10284bc02dd.bindPopup(popup_92dc95bb1983973407a14af72fdf61ce)
#         ;
#
#
#
#
#             var marker_247671688bad1ee41dab684dda1b4d9e = L.marker(
#                 [12.9757, 77.5929],
#                 {}
#             ).addTo(map_9d1793ca40ff6fac4b80d3e102708571);
#
#
#         var popup_cbd0511f6a1dba6b3b9544f51bbeb3d0 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_771a9de7228179de903b443cee895e03 = $(`&lt;div id=&quot;html_771a9de7228179de903b443cee895e03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Cubbon Park&lt;/b&gt;&lt;br&gt;&lt;img src=&quot;https://tse1.mm.bing.net/th?id=OIP.G-kjAcQb59k6I1vQ_XcHEwHaE8&amp;pid=Api&amp;P=0&amp;h=180&quot; width=&quot;200&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_cbd0511f6a1dba6b3b9544f51bbeb3d0.setContent(html_771a9de7228179de903b443cee895e03);
#
#
#
#         marker_247671688bad1ee41dab684dda1b4d9e.bindPopup(popup_cbd0511f6a1dba6b3b9544f51bbeb3d0)
#         ;
#
#
#
#
#             var marker_8d4fc36deb2f2a9f7c2cc2b66602b0e0 = L.marker(
#                 [12.97194, 77.5936],
#                 {}
#             ).addTo(map_9d1793ca40ff6fac4b80d3e102708571);
#
#
#         var popup_bb0a7355196346aa7390bb6d30e1cb3c = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_37f70bb6c873942941aa96555db13a91 = $(`&lt;div id=&quot;html_37f70bb6c873942941aa96555db13a91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Bangalore Palace&lt;/b&gt;&lt;br&gt;&lt;img src=&quot;https://tse2.mm.bing.net/th?id=OIP.i8dzBHIHgsZ0D9JK9tzSMwHaEo&amp;pid=Api&amp;P=0&amp;h=180&quot; width=&quot;200&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_bb0a7355196346aa7390bb6d30e1cb3c.setContent(html_37f70bb6c873942941aa96555db13a91);
#
#
#
#         marker_8d4fc36deb2f2a9f7c2cc2b66602b0e0.bindPopup(popup_bb0a7355196346aa7390bb6d30e1cb3c)
#         ;
#
#
#
#
#             var marker_a4b1ea6a5cb9c80864d9c5bd0084518d = L.marker(
#                 [12.979693, 77.590658],
#                 {}
#             ).addTo(map_9d1793ca40ff6fac4b80d3e102708571);
#
#
#         var popup_d5fabcbfce3ef4efb60cf9691f95fdfa = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_bc4e38c50a06cbb89bab4072d496048a = $(`&lt;div id=&quot;html_bc4e38c50a06cbb89bab4072d496048a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Vidhana Soudha&lt;/b&gt;&lt;br&gt;&lt;img src=&quot;https://tse3.mm.bing.net/th?id=OIP.LMgE0-vo4Fk26srdnaMdYgHaFj&amp;pid=Api&amp;P=0&amp;h=180&quot; width=&quot;200&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_d5fabcbfce3ef4efb60cf9691f95fdfa.setContent(html_bc4e38c50a06cbb89bab4072d496048a);
#
#
#
#         marker_a4b1ea6a5cb9c80864d9c5bd0084518d.bindPopup(popup_d5fabcbfce3ef4efb60cf9691f95fdfa)
#         ;
#
#
#
#
#             var marker_78df293d2121c0867693b1c2d3142aae = L.marker(
#                 [13.1682, 77.5354],
#                 {}
#             ).addTo(map_9d1793ca40ff6fac4b80d3e102708571);
#
#
#         var popup_e5fdf7c774303a092ebdf2090b25e4d4 = L.popup({&
